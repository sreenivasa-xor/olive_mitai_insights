# %%
# %sql
create catalog if not exists oliv_mitai_uc;

# %%
# %sql
use catalog oliv_mitai_uc;
    
create schema if not exists bronze;
create schema if not exists silver;
create schema if not exists gold;

# %%
# %sql
create volume if not exists olive_mitai_raw_data
