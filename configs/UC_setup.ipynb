# %%
# %sql
create catalog if not exists oliv_mitai_uc;

# %%
# %sql
use catalog oliv_mitai_uc;
    
create schema if not exists bronze;
create schema if not exists silver;
create schema if not exists gold;

# %%
# %sql
create volume if not exists olive_mitai_raw_data

# %%
# %sql
-- drop table if exists oliv_mitai_uc.bronze.olive_mitai_sales;
-- drop table if exists oliv_mitai_uc.silver.sales_silver;
-- drop table if exists oliv_mitai_uc.silver.invalid_sales;
-- drop table if exists oliv_mitai_uc.gold.dim_date;
-- drop table if exists oliv_mitai_uc.gold.dim_store;
-- drop table if exists oliv_mitai_uc.gold.dim_payment_method;
